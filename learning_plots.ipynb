# %%
from baselines.common import plot_util as pu
import matplotlib.pyplot as plt
import numpy as np
import gym
import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
envs = ['Reacher-v2',
        'InvertedPendulum-v2',
        'Walker2d-v2',
        'Humanoid-v2',
        'HalfCheetah-v2',
        'InvertedDoublePendulum-v2']

# %%
for env_name in envs:
    env = gym.make(env_name)
    env.reset()
    
    print(env_name)
    print('observation space:')
    print(env.observation_space)
    print('action space:')
    print(env.action_space)
    print()
# Out:
# Reacher-v2
# observation space:
# Box(11,)
# action space:
# Box(2,)
#
# InvertedPendulum-v2
# observation space:
# Box(4,)
# action space:
# Box(1,)
#
# Walker2d-v2
# observation space:
# Box(17,)
# action space:
# Box(6,)
#
# Humanoid-v2
# observation space:
# Box(376,)
# action space:
# Box(17,)
#
# HalfCheetah-v2
# observation space:
# Box(17,)
# action space:
# Box(6,)
#
# InvertedDoublePendulum-v2
# observation space:
# Box(11,)
# action space:
# Box(1,)

# %%
logs_dir = '/home/danielzgsilva/Documents/robotics_project/logs'

# %%
for env_name in envs:
    exp_dir = os.path.join(logs_dir, env_name)
    results = pu.load_results(exp_dir) 
    print(env_name)
    f, ax = pu.plot_results(results, split_fn=lambda _: '', 
                            legend_outside=True, xlabel='Timesteps', ylabel='Reward')
# Out:
# Reacher-v2
# InvertedPendulum-v2
# Walker2d-v2
# Humanoid-v2
# HalfCheetah-v2
# InvertedDoublePendulum-v2
# FetchReach-v1
